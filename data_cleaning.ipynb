# %%
import pandas as pd

# Google Play store apps data
df = pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-TheCompleteGuide/main/googleplaystore.csv")
df
# Out:
# /Users/im-lp-c-72/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# ...

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
df.sample()
# Out:
#                             App            Category  Rating Reviews  \
# 3762  BeyondPod Podcast Manager  NEWS_AND_MAGAZINES     3.9   32121
#
#                     Size    Installs  Type Price Content Rating  \
# 3762  Varies with device  1,000,000+  Free     0       Everyone
#
#                 Genres    Last Updated         Current Ver         Android Ver
# 3762  News & Magazines  April 13, 2018  Varies with device  Varies with device

# %%
df.sample(10)
# Out:
#                                                      App            Category  \
# 6540                          BN Pro Black Text on White  LIBRARIES_AND_DEMO
# 1264     Step Counter - Pedometer Free & Calorie Counter  HEALTH_AND_FITNESS
# 339                Messenger Lite: Free Calls & Messages       COMMUNICATION
# 6992   Glitter Color By Number - Glitter Number Coloring              FAMILY
# 6689                                          Tv Br News              FAMILY
# 1771                 Color by Number – New Coloring Book                GAME
# 9447                             TAMAGO Monsters Returns                GAME
# 10388                              Field Goal Tournament              SPORTS
# 6772                       BT Find Address for Bluetooth            BUSINESS
# 9353                   L.A. Crime Stories Mad City Crime                GAME
#
#        Rating  Reviews                Size      Installs  Type Price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# sample is random selection

df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.describe().T
# Out:
#          count      mean       std  min  25%  50%  75%   max
# Rating  9367.0  4.193338  0.537431  1.0  4.0  4.3  4.5  19.0

# %%
# price Object not correct 

df.describe(include='all').T
# Out:
#                  count unique                 top   freq      mean       std  \
# App              10841   9660              ROBLOX      9       NaN       NaN
# Category         10841     34              FAMILY   1972       NaN       NaN
# Rating          9367.0    NaN                 NaN    NaN  4.193338  0.537431
# Reviews          10841   6002                   0    596       NaN       NaN
# Size             10841    462  Varies with device   1695       NaN       NaN
# Installs         10841     22          1,000,000+   1579       NaN       NaN
# Type             10840      3                Free  10039       NaN       NaN
# Price            10841     93                   0  10040       NaN       NaN
# Content Rating   10840      6            Everyone   8714       NaN       NaN
# Genres           10841    120               Tools    842       NaN       NaN
# Last Updated     10841   1378      August 3, 2018    326       NaN       NaN
# ...

# %%
# check duplicate data

df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df['Reviews'].head(20)
# Out:
# 0        159
# 1        967
# 2      87510
# 3     215644
# 4        967
# 5        167
# 6        178
# 7      36815
# 8      13791
# 9        121
# 10     13880
# 11      8788
# 12     44829
# 13      4326
# 14      1518
# 15        55
# 16      3632
# 17        27
# 18    194216
# 19    224399
# Name: Reviews, dtype: object

# %%
df['Reviews'].shape
# Out:
# (10841,)

# %%
df['Reviews'].dtype
# Out:
# dtype('O')

# %%
df['Reviews'].str

# %%
df['Reviews'].str.isnumeric()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 10836    True
# 10837    True
# 10838    True
# 10839    True
# 10840    True
# Name: Reviews, Length: 10841, dtype: bool

# %%
df[~df['Reviews'].str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
# only 1 vlaue in review is 3.0M remaining all numeric
# dropping row 10472 , considered as outlier // drop or interpret

df1 = df.copy()
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df1.index[10472]
# Out:
# 10472

# %%
df1.shape
# Out:
# (10841, 13)

# %%
df1 = df1.drop(df1.index[10472])
df1.shape
# Out:
# (10840, 13)

# %%
# use iloc to remove more rows 

# changing data type of column from Obj to int

df1['Reviews'] = df1['Reviews'].astype('int')

# %%
df1['Reviews'].dtype
# Out:
# dtype('int64')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.2+ MB

# %%
df1["Size"]
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10836                   53M
# 10837                  3.6M
# 10838                  9.5M
# 10839    Varies with device
# 10840                   19M
# Name: Size, Length: 10840, dtype: object

# %%
df1["Size"].dtype
# Out:
# dtype('O')

# %%
df1['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
# replace k with 1000 and M with 10000000

df1['Size'] = df1['Size'].str.replace('M','000k')

# %%
df1['Size']
# Out:
# 0                    19000k
# 1                    14000k
# 2                   8.7000k
# 3                    25000k
# 4                   2.8000k
#                 ...
# 10836                53000k
# 10837               3.6000k
# 10838               9.5000k
# 10839    Varies with device
# 10840                19000k
# Name: Size, Length: 10840, dtype: object

# %%
df1['Size'].unique()
# Out:
# array(['19000k', '14000k', '8.7000k', '25000k', '2.8000k', '5.6000k',
#        '29000k', '33000k', '3.1000k', '28000k', '12000k', '20000k',
#        '21000k', '37000k', '2.7000k', '5.5000k', '17000k', '39000k',
#        '31000k', '4.2000k', '7.0000k', '23000k', '6.0000k', '6.1000k',
#        '4.6000k', '9.2000k', '5.2000k', '11000k', '24000k',
#        'Varies with device', '9.4000k', '15000k', '10000k', '1.2000k',
#        '26000k', '8.0000k', '7.9000k', '56000k', '57000k', '35000k',
#        '54000k', '201k', '3.6000k', '5.7000k', '8.6000k', '2.4000k',
#        '27000k', '2.5000k', '16000k', '3.4000k', '8.9000k', '3.9000k',
#        '2.9000k', '38000k', '32000k', '5.4000k', '18000k', '1.1000k',
#        '2.2000k', '4.5000k', '9.8000k', '52000k', '9.0000k', '6.7000k',
#        '30000k', '2.6000k', '7.1000k', '3.7000k', '22000k', '7.4000k',
#        '6.4000k', '3.2000k', '8.2000k', '9.9000k', '4.9000k', '9.5000k',
# ...

# %%
import numpy as np
df1['Size'] = df1['Size'].str.replace('Varies with device',str(np.nan))

# %%
df1['Size'].unique()
# Out:
# array(['19000k', '14000k', '8.7000k', '25000k', '2.8000k', '5.6000k',
#        '29000k', '33000k', '3.1000k', '28000k', '12000k', '20000k',
#        '21000k', '37000k', '2.7000k', '5.5000k', '17000k', '39000k',
#        '31000k', '4.2000k', '7.0000k', '23000k', '6.0000k', '6.1000k',
#        '4.6000k', '9.2000k', '5.2000k', '11000k', '24000k', 'nan',
#        '9.4000k', '15000k', '10000k', '1.2000k', '26000k', '8.0000k',
#        '7.9000k', '56000k', '57000k', '35000k', '54000k', '201k',
#        '3.6000k', '5.7000k', '8.6000k', '2.4000k', '27000k', '2.5000k',
#        '16000k', '3.4000k', '8.9000k', '3.9000k', '2.9000k', '38000k',
#        '32000k', '5.4000k', '18000k', '1.1000k', '2.2000k', '4.5000k',
#        '9.8000k', '52000k', '9.0000k', '6.7000k', '30000k', '2.6000k',
#        '7.1000k', '3.7000k', '22000k', '7.4000k', '6.4000k', '3.2000k',
#        '8.2000k', '9.9000k', '4.9000k', '9.5000k', '5.0000k', '5.9000k',
# ...

# %%
df1['Size'] = df1['Size'].str.replace('k','')

# %%
df1['Size'].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'nan', '9.4000', '15000', '10000', '1.2000', '26000',
#        '8.0000', '7.9000', '56000', '57000', '35000', '54000', '201',
#        '3.6000', '5.7000', '8.6000', '2.4000', '27000', '2.5000', '16000',
#        '3.4000', '8.9000', '3.9000', '2.9000', '38000', '32000', '5.4000',
#        '18000', '1.1000', '2.2000', '4.5000', '9.8000', '52000', '9.0000',
#        '6.7000', '30000', '2.6000', '7.1000', '3.7000', '22000', '7.4000',
#        '6.4000', '3.2000', '8.2000', '9.9000', '4.9000', '9.5000',
#        '5.0000', '5.9000', '13000', '73000', '6.8000', '3.5000', '4.0000',
#        '2.3000', '7.2000', '2.1000', '42000', '7.3000', '9.1000', '55000',
# ...

# %%
df1['Size'] = df1['Size'].astype('float')

# %%
df1.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df1['Size'].head()
# Out:
# 0    19000.0
# 1    14000.0
# 2        8.7
# 3    25000.0
# 4        2.8
# Name: Size, dtype: float64

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
df1['Size'].unique
# Out:
# <bound method Series.unique of 0        19000.0
# 1        14000.0
# 2            8.7
# 3        25000.0
# 4            2.8
#           ...
# 10836    53000.0
# 10837        3.6
# 10838        9.5
# 10839        NaN
# 10840    19000.0
# Name: Size, Length: 10840, dtype: float64>

# %%
for i in df1['Size']:
    if i < 10:
        df1['Size'] = df1['Size'].replace(i,i*1000)

# %%
df1['Size'].unique()
# Out:
# array([1.90e+04, 1.40e+04, 8.70e+03, 2.50e+04, 2.80e+03, 5.60e+03,
#        2.90e+04, 3.30e+04, 3.10e+03, 2.80e+04, 1.20e+04, 2.00e+04,
#        2.10e+04, 3.70e+04, 2.70e+03, 5.50e+03, 1.70e+04, 3.90e+04,
#        3.10e+04, 4.20e+03, 7.00e+03, 2.30e+04, 6.00e+03, 6.10e+03,
#        4.60e+03, 9.20e+03, 5.20e+03, 1.10e+04, 2.40e+04,      nan,
#        9.40e+03, 1.50e+04, 1.00e+04, 1.20e+03, 2.60e+04, 8.00e+03,
#        7.90e+03, 5.60e+04, 5.70e+04, 3.50e+04, 5.40e+04, 2.01e+02,
#        3.60e+03, 5.70e+03, 8.60e+03, 2.40e+03, 2.70e+04, 2.50e+03,
#        1.60e+04, 3.40e+03, 8.90e+03, 3.90e+03, 2.90e+03, 3.80e+04,
#        3.20e+04, 5.40e+03, 1.80e+04, 1.10e+03, 2.20e+03, 4.50e+03,
#        9.80e+03, 5.20e+04, 9.00e+03, 6.70e+03, 3.00e+04, 2.60e+03,
#        7.10e+03, 3.70e+03, 2.20e+04, 7.40e+03, 6.40e+03, 3.20e+03,
#        8.20e+03, 9.90e+03, 4.90e+03, 9.50e+03, 5.00e+03, 5.90e+03,
#        1.30e+04, 7.30e+04, 6.80e+03, 3.50e+03, 4.00e+03, 2.30e+03,
# ...

# %%
df1['Size'].head(50)
# Out:
# 0     19000.0
# 1     14000.0
# 2      8700.0
# 3     25000.0
# 4      2800.0
# 5      5600.0
# 6     19000.0
# 7     29000.0
# 8     33000.0
# 9      3100.0
# 10    28000.0
# 11    12000.0
# 12    20000.0
# 13    21000.0
# 14    37000.0
# 15     2700.0
# 16     5500.0
# 17    17000.0
# 18    39000.0
# 19    31000.0
# 20    14000.0
# 21    12000.0
# 22     4200.0
# 23     7000.0
# 24    23000.0
# 25     6000.0
# 26    25000.0
# 27     6100.0
# 28     4600.0
# 29     4200.0
# 30     9200.0
# 31     5200.0
# 32    11000.0
# 33    11000.0
# 34     4200.0
# 35     9200.0
# 36    24000.0
# 37        NaN
# 38    11000.0
# 39     9400.0
# 40    15000.0
# 41    10000.0
# 42        NaN
# 43     1200.0
# 44    12000.0
# 45    24000.0
# 46    26000.0
# 47     8000.0
# 48     7900.0
# 49    25000.0
# Name: Size, dtype: float64

# %%
df1.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df1["Installs"] = df1["Installs"].str.replace("+","")

# %%
df1["Installs"]
# Out:
# 0            10,000
# 1           500,000
# 2         5,000,000
# 3        50,000,000
# 4           100,000
#             ...
# 10836         5,000
# 10837           100
# 10838         1,000
# 10839         1,000
# 10840    10,000,000
# Name: Installs, Length: 10840, dtype: object

# %%
df1["Installs"].dtype
# Out:
# dtype('O')

# %%
df1["Installs"].str

# %%
type(df1["Installs"][0])
# Out:
# str

# %%
df1.head(50)
# Out:
#                                                   App           Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                 Coloring book moana     ART_AND_DESIGN
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                               Sketch - Draw & Paint     ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# 5                          Paper flowers instructions     ART_AND_DESIGN
# 6             Smoke Effect Photo Maker - Smoke Editor     ART_AND_DESIGN
# 7                                    Infinite Painter     ART_AND_DESIGN
# 8                                Garden Coloring Book     ART_AND_DESIGN
# 9                       Kids Paint Free - Drawing Fun     ART_AND_DESIGN
# 10                            Text on Photo - Fonteee     ART_AND_DESIGN
# 11            Name Art Photo Editor - Focus n Filters     ART_AND_DESIGN
# ...

# %%
char_2remove = ["+",",","$"]
cols_2clean = ["Price", "Installs"]
for item in char_2remove:
    for col in cols_2clean:
        df1[col] = df1[col].str.replace(item,'')

# %%
df1["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df1["Price"].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.4+ MB

# %%
df1["Installs"] = df1["Installs"].astype('int')
df1["Price"] = df1["Price"].astype('float')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.4+ MB

# %%
df1["Last Updated"]
# Out:
# 0         January 7, 2018
# 1        January 15, 2018
# 2          August 1, 2018
# 3            June 8, 2018
# 4           June 20, 2018
#                ...
# 10836       July 25, 2017
# 10837        July 6, 2018
# 10838    January 20, 2017
# 10839    January 19, 2015
# 10840       July 25, 2018
# Name: Last Updated, Length: 10840, dtype: object

# %%
df1["Last Updated"].dtype
# Out:
# dtype('O')

# %%
# last update is Date time data type

df1["Last Updated"] = pd.to_datetime(df1["Last Updated"])

# %%
df1.dtypes
# Out:
# App                       object
# Category                  object
# Rating                   float64
# Reviews                    int64
# Size                     float64
# Installs                   int64
# Type                      object
# Price                    float64
# Content Rating            object
# Genres                    object
# Last Updated      datetime64[ns]
# Current Ver               object
# Android Ver               object
# dtype: object

# %%
df1["Last Updated"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df1["Last Updated"].dt.day
# Out:
# 0         7
# 1        15
# 2         1
# 3         8
# 4        20
#          ..
# 10836    25
# 10837     6
# 10838    20
# 10839    19
# 10840    25
# Name: Last Updated, Length: 10840, dtype: int32

# %%
df1["Last Updated"].dt.month
# Out:
# 0        1
# 1        1
# 2        8
# 3        6
# 4        6
#         ..
# 10836    7
# 10837    7
# 10838    1
# 10839    1
# 10840    7
# Name: Last Updated, Length: 10840, dtype: int32

# %%
df1["Last Updated"].dt.year
# Out:
# 0        2018
# 1        2018
# 2        2018
# 3        2018
# 4        2018
#          ...
# 10836    2017
# 10837    2018
# 10838    2017
# 10839    2015
# 10840    2018
# Name: Last Updated, Length: 10840, dtype: int32

# %%
df1["day"] = df1["Last Updated"].dt.day
df1["month"] = df1["Last Updated"].dt.month
df1["year"] = df1["Last Updated"].dt.year

# %%
df1["Android Ver"]
# Out:
# 0              4.0.3 and up
# 1              4.0.3 and up
# 2              4.0.3 and up
# 3                4.2 and up
# 4                4.4 and up
#                 ...
# 10836            4.1 and up
# 10837            4.1 and up
# 10838            2.2 and up
# 10839    Varies with device
# 10840    Varies with device
# Name: Android Ver, Length: 10840, dtype: object

# %%
df1["Android Ver"] = df1["Android Ver"].str.replace(" and up","")

# %%
df1["Android Ver"]
# Out:
# 0                     4.0.3
# 1                     4.0.3
# 2                     4.0.3
# 3                       4.2
# 4                       4.4
#                 ...
# 10836                   4.1
# 10837                   4.1
# 10838                   2.2
# 10839    Varies with device
# 10840    Varies with device
# Name: Android Ver, Length: 10840, dtype: object

# %%
df1["Android Ver"] = df1["Android Ver"].str.replace("Varies with device",str(np.nan))

# %%
df1["Android Ver"]
# Out:
# 0        4.0.3
# 1        4.0.3
# 2        4.0.3
# 3          4.2
# 4          4.4
#          ...
# 10836      4.1
# 10837      4.1
# 10838      2.2
# 10839      nan
# 10840      nan
# Name: Android Ver, Length: 10840, dtype: object

# %%
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df1["Current Ver"] = df1["Current Ver"].str.replace(" and up","")
df1["Current Ver"] = df1["Current Ver"].str.replace("Varies with device",str(np.nan))
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df1.to_csv("cleaned_google_playstore_data.csv",index=False)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# Sweetviz , Autoviz, dtale, data prep, Pandas profile,
